# %%
# !pip install -Uqq fastbook

import fastbook
fastbook.setup_book()
from fastbook import *
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 4.2.0 requires pyqt5<5.13, which is not installed.
# spyder 4.2.0 requires pyqtwebengine<5.13, which is not installed.
# aiobotocore 1.3.0 requires botocore<1.20.50,>=1.20.49, but you have botocore 1.24.12 which is incompatible.
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/fastbook/__init__.py:19: UserWarning: Missing `graphviz` - please run `conda install fastbook`
#   except ModuleNotFoundError: warn("Missing `graphviz` - please run `conda install fastbook`")

# %%
#!pip install bing-image-downloader
#from bing_image_downloader import downloader
#from pathlib import Path

downloader.download("siberian husky", limit=150, output_dir='dogs', adult_filter_off=True, force_replace=False, timeout=5)
downloader.download("alaskan malamute", limit=150, output_dir='dogs', adult_filter_off=True, force_replace=False, timeout=5)
downloader.download("samoyed", limit=150, output_dir='dogs', adult_filter_off=True, force_replace=False, timeout=5)

path = Path('dogs/siberian husky')
path.rename('dogs/husky')
path = Path('dogs/alaskan malamute')
path.rename('dogs/malamute')
path = Path('dogs/samoyed')
# Out:
# [%] Downloading Images to /home/ec2-user/SageMaker/fastbook/dogs/siberian husky
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 9 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.luxurypuppies2u.com/wp-content/uploads/2021/02/IMG_4815-scaled.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.breedyourdog.com/uploads/listing_images/21003/52409/big_20150712_131844-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/736x/2f/18/58/2f1858f4827da2e7b00d6f63738ce8ea.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.pinimg.com/736x/bf/40/2b/bf402bfff9402931231a940aeb822b1c--siberian-huskies-husky.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.pinimg.com/736x/3f/91/fe/3f91fedbbbc053889bd1cfc2aa0b135c--the-ocean-husky-pups.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://ratses.gr/sites/default/files/Huski.jpg
# [%] File Downloaded !
#
# ...

# %%
path = Path('dogs')

# %%
fns = get_image_files(path)
fns
# Out:
# (#449) [Path('dogs/husky/Image_107.jpg'),Path('dogs/husky/Image_130.jpg'),Path('dogs/husky/Image_38.jpg'),Path('dogs/husky/Image_119.jpg'),Path('dogs/husky/Image_50.jpg'),Path('dogs/husky/Image_2.jpg'),Path('dogs/husky/Image_96.jpg'),Path('dogs/husky/Image_137.jpg'),Path('dogs/husky/Image_111.jpg'),Path('dogs/husky/Image_97.jpg')...]

# %%
failed = verify_images(fns)
failed
# Out:
# (#0) []

# %%
failed.map(Path.unlink);

# %%
dogs = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = dogs.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/PIL/Image.py:976: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "

# %%
dogs = dogs.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = dogs.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.536419</td>
#       <td>0.993118</td>
#       <td>0.413793</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
#interp.plot_top_losses(5, nrows=1)

# %%
from fastai.vision.widgets import *

# %%
#hide_output
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ...

# %%
#for idx in cleaner.delete(): cleaner.fns[idx].unlink()
#for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %%
learn.export()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('images/ash.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('samoyed', tensor(2), tensor([0.0604, 0.1569, 0.7827]))

# %%
learn_inf.dls.vocab
# Out:
# ['husky', 'malamute', 'samoyed']

# %%
#hide_output
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images/ash.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
#hide_output
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
#hide_output
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: samoyed; Probability: 0.7827')

# %%
#hide_output
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
#hide_output
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
